# %%
ice_cream_rating = 8
sleeping_rating = 8

# %%
first_name=input('What is your first name?')
last_name=input('What is your last name?')
my_name=first_name+' '+last_name
# Out:
# What is your first name? Alexander
# What is your last name? Hizkia

# %%
happiness_rating=(ice_cream_rating+sleeping_rating)/2

# %%
x=type(ice_cream_rating)
y=type(sleeping_rating)
z=type(happiness_rating)
print(x,y,z)
# Out:
# <class 'int'> <class 'int'> <class 'float'>

# %% [markdown]
# Make sense, happiness_rating data types different than the other as i expected because it has decimal value

# %%
print('My name is', first_name, 'I give eating ice cream a score of', ice_cream_rating, 'out of 10')
print('I am', my_name, 'and my sleeping enjoyment rating is', sleeping_rating, '/ 10')
print('Based on the factors above, my happiness rating is', happiness_rating, 'out of 10, or 80.0 %')
# Out:
# My name is Alexander I give eating ice cream a score of 8 out of 10
# I am Alexander Hizkia and my sleeping enjoyment rating is 8 / 10
# Based on the factors above, my happiness rating is 8.0 out of 10, or 80.0 %
